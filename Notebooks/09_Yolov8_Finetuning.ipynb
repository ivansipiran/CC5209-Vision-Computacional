# %% [markdown]
# # Fine-tuning de un detector YOLO con Ultralytics
#
# Este notebook conserva el propósito del antiguo ejemplo YOLOv8, pero usa el flujo Python documentado actualmente por Ultralytics. La familia recomendada puede cambiar; MODEL_NAME concentra esa decisión en una línea.
#
# **Conceptos:** detección versus clasificación, cajas, confianza, IoU, fine-tuning, validación, mAP y formato de un dataset YOLO.
#
# **Resultado esperado:** primero veremos detecciones preentrenadas y luego completaremos un smoke test de entrenamiento con COCO8. Ocho imágenes sirven para verificar el pipeline, no para afirmar generalización.

# %% [markdown]
# ## 1. Instalación y entorno
#
# Instalamos una versión actual de la biblioteca dentro de la serie 8 y registramos la versión efectiva. En un entorno de producción conviene copiar esa versión a requirements.txt después de verificar el notebook.

# %%
# !pip install -q "ultralytics>=8.3.0,<9.0.0"

# %%
import json
from pathlib import Path

import cv2
import matplotlib.pyplot as plt
import torch
import ultralytics
from ultralytics import YOLO

device = 0 if torch.cuda.is_available() else "cpu"
output_root = Path("outputs/yolo_detection")
output_root.mkdir(parents=True, exist_ok=True)

print("Ultralytics:", ultralytics.__version__)
print("PyTorch:", torch.__version__)
print("Dispositivo:", device)

# %% [markdown]
# ## 2. Inferencia con pesos preentrenados
#
# Un detector devuelve varias cajas por imagen. Cada caja tiene una clase y un puntaje de confianza. Usamos una imagen remota pública y no guardamos resultados todavía.
#
# **Resultado esperado:** cajas sobre objetos comunes de la escena. Un umbral bajo muestra más detecciones y también más falsos positivos.

# %%
MODEL_NAME = "yolo26n.pt"
sample_image_url = "https://ultralytics.com/images/bus.jpg"

pretrained_model = YOLO(MODEL_NAME)
pretrained_results = pretrained_model.predict(
    source=sample_image_url,
    conf=0.25,
    device=device,
    save=False,
    verbose=False,
)

# result.plot devuelve una imagen BGR porque usa convenciones de OpenCV.
annotated_bgr = pretrained_results[0].plot()
annotated_rgb = cv2.cvtColor(annotated_bgr, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(12, 8))
plt.imshow(annotated_rgb)
plt.title("Detecciones del modelo preentrenado")
plt.axis("off")
plt.show()

# %% [markdown]
# ## 3. Dataset de comprobación COCO8
#
# COCO8 contiene cuatro imágenes de train y cuatro de validación. Ultralytics lo descarga automáticamente al usar data="coco8.yaml".
#
# Es útil para comprobar instalación, lectura de etiquetas, forward, backward, guardado y evaluación. Es demasiado pequeño para comparar modelos científicamente.

# %% [markdown]
# Una etiqueta YOLO ocupa una línea por objeto:
#
# clase  centro_x  centro_y  ancho  alto
#
# Las cuatro coordenadas están normalizadas entre 0 y 1. Para un dataset propio se necesita una carpeta de imágenes, sus archivos .txt y un YAML como este:
#
#     path: /ruta/al/dataset
#     train: images/train
#     val: images/val
#     test: images/test
#     names:
#       0: primera_clase
#       1: segunda_clase
#
# Antes de entrenar, conviene visualizar cajas y verificar que clase y coordenadas sean correctas.

# %%
import requests
from zipfile import ZipFile

import yaml

local_dataset_root = Path("data/coco8")
local_dataset_archive = Path("data/coco8.zip")
local_data_config = Path("data/coco8_course.yaml")
local_dataset_archive.parent.mkdir(parents=True, exist_ok=True)

if not (local_dataset_root / "images/train").exists():
    if not local_dataset_archive.exists():
        response = requests.get(
            "https://ultralytics.com/assets/coco8.zip",
            timeout=60,
        )
        response.raise_for_status()
        local_dataset_archive.write_bytes(response.content)

    with ZipFile(local_dataset_archive) as archive:
        archive.extractall(local_dataset_archive.parent)

dataset_description = {
    "path": str(local_dataset_root.resolve()),
    "train": "images/train",
    "val": "images/val",
    "names": pretrained_model.names,
}
with local_data_config.open("w", encoding="utf-8") as yaml_file:
    yaml.safe_dump(
        dataset_description,
        yaml_file,
        sort_keys=False,
        allow_unicode=True,
    )

DATA_CONFIG = str(local_data_config.resolve())
print("Configuración local:", DATA_CONFIG)

# %% [markdown]
# ## 4. Configuración reproducible y entrenamiento
#
# Tres épocas bastan para un smoke test. En un experimento real se debe aumentar EPOCHS, usar más datos y justificar hiperparámetros.
#
# project y name hacen predecible la carpeta de salida. seed y deterministic reducen variación.
#
# **Resultado esperado:** se crea un directorio con pesos, curvas y configuración. El resultado numérico sobre COCO8 no debe reportarse como desempeño representativo.

# %%
EPOCHS = 3
IMAGE_SIZE = 640
BATCH_SIZE = 8
SEED = 42
RUN_NAME = f"coco8_{MODEL_NAME.replace('.pt', '')}_seed{SEED}"

detection_model = YOLO(MODEL_NAME)
training_metrics = detection_model.train(
    data=DATA_CONFIG,
    epochs=EPOCHS,
    imgsz=IMAGE_SIZE,
    batch=BATCH_SIZE,
    seed=SEED,
    deterministic=True,
    device=device,
    workers=0,
    project=str(output_root),
    name=RUN_NAME,
    exist_ok=True,
    plots=True,
)

run_directory = Path(detection_model.trainer.save_dir)
best_weights_path = run_directory / "weights" / "best.pt"
if not best_weights_path.exists():
    raise FileNotFoundError(
        f"No se encontró el checkpoint esperado: {best_weights_path}"
    )

experiment_config = {
    "ultralytics_version": ultralytics.__version__,
    "model": MODEL_NAME,
    "data": DATA_CONFIG,
    "epochs": EPOCHS,
    "image_size": IMAGE_SIZE,
    "batch_size": BATCH_SIZE,
    "seed": SEED,
    "device": str(device),
}
with (run_directory / "course_experiment.json").open(
    "w",
    encoding="utf-8",
) as config_file:
    json.dump(experiment_config, config_file, indent=2)

print("Resultados:", run_directory)
print("Mejores pesos:", best_weights_path)

# %% [markdown]
# Ultralytics guarda una figura results.png con pérdidas y métricas por época.
#
# **Resultado esperado:** con solo tres épocas y ocho imágenes, las curvas pueden ser inestables. Su función aquí es verificar que se registran correctamente.

# %%
results_figure_path = run_directory / "results.png"
if results_figure_path.exists():
    results_bgr = cv2.imread(str(results_figure_path))
    plt.figure(figsize=(14, 8))
    plt.imshow(cv2.cvtColor(results_bgr, cv2.COLOR_BGR2RGB))
    plt.title("Curvas generadas por Ultralytics")
    plt.axis("off")
    plt.show()
else:
    print("La versión instalada no generó results.png.")

# %% [markdown]
# ## 5. Validación
#
# - **Precision:** fracción de detecciones propuestas que son correctas.
# - **Recall:** fracción de objetos reales que fueron detectados.
# - **mAP@50:** promedio de average precision con IoU 0.50.
# - **mAP@50–95:** promedio sobre umbrales IoU 0.50, 0.55, ..., 0.95; es más estricto.
#
# Separamos estas métricas porque una sola cifra puede ocultar falsos positivos o falsos negativos.

# %%
best_model = YOLO(str(best_weights_path))
validation_metrics = best_model.val(
    data=DATA_CONFIG,
    split="val",
    device=device,
    workers=0,
    verbose=False,
)

print(f"Precision media: {validation_metrics.box.mp:.4f}")
print(f"Recall medio:    {validation_metrics.box.mr:.4f}")
print(f"mAP@50:          {validation_metrics.box.map50:.4f}")
print(f"mAP@50-95:       {validation_metrics.box.map:.4f}")

# %% [markdown]
# ## 6. Inferencia con el checkpoint ajustado
#
# Aplicamos el checkpoint al mismo ejemplo visual. Como COCO8 es diminuto, no esperamos una mejora confiable respecto de los pesos originales.
#
# **Resultado esperado:** se muestran las cajas que superan conf=0.25. Si no aparece una clase, puede deberse al umbral, los datos o el entrenamiento insuficiente.

# %%
finetuned_results = best_model.predict(
    source=sample_image_url,
    conf=0.25,
    device=device,
    save=False,
    verbose=False,
)
finetuned_bgr = finetuned_results[0].plot()

plt.figure(figsize=(12, 8))
plt.imshow(cv2.cvtColor(finetuned_bgr, cv2.COLOR_BGR2RGB))
plt.title("Inferencia con el checkpoint del smoke test")
plt.axis("off")
plt.show()

# %% [markdown]
# ## 7. Ejercicios
#
# **Ejercicio 1 — Umbral de confianza.** Compare conf=0.10, 0.25 y 0.70 en la misma imagen.
#
# **Resultado esperado:** subir el umbral reduce detecciones; puede disminuir falsos positivos y aumentar falsos negativos.
#
# **Ejercicio 2 — Dataset propio.** Reemplace DATA_CONFIG por su YAML. Antes de entrenar, visualice al menos diez imágenes con sus etiquetas.
#
# **Resultado esperado:** todas las cajas deben caer sobre objetos y los índices deben coincidir con names.
#
# **Ejercicio 3 — Experimento controlado.** Compare el modelo nano actual con yolov8n.pt usando la misma partición, semilla, épocas e imagen.
#
# **Resultado esperado:** reporte tiempo, memoria y métricas reales; no atribuya diferencias a la arquitectura sin repetir semillas.
#
# **Checklist:** datos inspeccionados, YAML versionado, semilla registrada, checkpoint trazable y test separado de decisiones de entrenamiento.
